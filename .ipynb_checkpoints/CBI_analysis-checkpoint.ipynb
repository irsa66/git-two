# %% [markdown]
# # Analysis of Global Unicorns in 2020

# %% [markdown]
# I shall analyse the csv file from CB Insights that contains information on all unicorns as of 2020. It contains informtaion on their valuations ($), investors and industry verticals.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('CBI_clean.csv')
df.head()
# Out:
#                  Company Valuation ($B)         Country  \
# 0    Toutiao (Bytedance)         $75.00           China
# 1           Didi Chuxing         $56.00           China
# 2                 Stripe         $36.00   United States
# 3                 SpaceX         $36.00   United States
# 4  Palantir Technologies         $20.00   United States
#
#                       Category  \
# 0      Artificial intelligence
# 1        Auto & transportation
# 2                      Fintech
# 3                        Other
# 4  Data management & analytics
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Matrix Partners, Tiger Global Management, Soft...
# 2        Khosla Ventures, LowercaseCapital, capitalG
# 3  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 4              RRE Ventures, Founders Fund, In-Q-Tel

# %%
df.columns
# Out:
# Index(['Company', 'Valuation ($B) ', 'Country', 'Category',
#        'Select Investors'],
#       dtype='object')

# %%
df.rename(columns = {'Select Investors' : 'Investors'}, inplace = True)

# %%
df.columns
# Out:
# Index(['Company', 'Valuation ($B) ', 'Country', 'Category', 'Investors'], dtype='object')

# %%
df.shape
# Out:
# (479, 5)

# %% [markdown]
# Checking for null values

# %%
df.isnull().sum()
# Out:
# Company            0
# Valuation ($B)     0
# Country            0
# Category           0
# Investors          1
# dtype: int64

# %%
empty = df[df['Investors'].isnull()]
print(empty)
# Out:
#               Company Valuation ($B)  Country                     Category  \
# 394  LinkSure Network          $1.00    China  Mobile & telecommunications
#
#     Investors
# 394       NaN

# %% [markdown]
# Company, LinkSure Network, at index 394 has NaN value for Investors

# %% [markdown]
# Extract the names of all investors

# %%
investors = df['Investors']

# %%
investors.head()
# Out:
# 0    Sequoia Capital China, SIG Asia Investments, S...
# 1    Matrix Partners, Tiger Global Management, Soft...
# 2          Khosla Ventures, LowercaseCapital, capitalG
# 3    Founders Fund, Draper Fisher Jurvetson, Rothen...
# 4                RRE Ventures, Founders Fund, In-Q-Tel
# Name: Investors, dtype: object

# %%
investors.str.split(',')
# Out:
# 0      [Sequoia Capital China,  SIG Asia Investments,...
# 1      [Matrix Partners,  Tiger Global Management,  S...
# 2        [Khosla Ventures,  LowercaseCapital,  capitalG]
# 3      [Founders Fund,  Draper Fisher Jurvetson,  Rot...
# 4              [RRE Ventures,  Founders Fund,  In-Q-Tel]
#                              ...
# 474    [Lightspeed Venture Partners,  Data Collective...
# 475    [Union Square Ventures,  Ribbit Capital,  VY C...
# 476    [dmg ventures,  General Catalyst,  Octopus Ven...
# 477                                               [Coty]
# 478    [Upper90,  RiverPark Ventures,  Advent Interna...
# Name: Investors, Length: 479, dtype: object

# %%
investors[0]
# Out:
# 'Sequoia Capital China, SIG Asia Investments, Sina Weibo, Softbank Group'

# %%
investors.unique()
# Out:
# array(['Sequoia Capital China, SIG Asia Investments, Sina Weibo, Softbank Group',
#        'Matrix Partners, Tiger Global Management, Softbank Corp.,',
#        'Khosla Ventures, LowercaseCapital, capitalG',
#        'Founders Fund, Draper Fisher Jurvetson, Rothenberg Ventures',
#        'RRE Ventures, Founders Fund, In-Q-Tel',
#        'General Catalyst Partners, Andreessen Horowitz, ENIAC Ventures',
#        'Morningside Venture Capital, Sequoia Capital, Baidu',
#        'Intel Capital, Sapphire Ventures, Alibaba Group',
#        'Softbank Group, Sequoia Capital, Khosla Ventures',
#        'Tencent Holdings, KKR, Smash Ventures',
#        'Accel Partners, Sequoia Capital',
#        'GGV Capital, Vertex Venture Holdings, Softbank Group',
#        'Tencent Holdings, Hillhouse Capital Management, Source Code Capital',
#        'Khosla Ventures, Kleiner Perkins Caufield & Byers, Collaborative Fund',
#        'Redpoint Ventures,Iconiq Capital, Madrona Venture Group',
# ...
